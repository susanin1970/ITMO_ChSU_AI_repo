# %%
# необходимые импорты
import numpy as np
import torch
import torchvision.datasets as dataset
import torchvision.transforms as transforms
from torch.utils.data import DataLoader, WeightedRandomSampler
import torch.nn.functional as F
import torch.nn as nn
import torch.optim as optim
from torchvision import models

import os
import cv2
import onnxruntime
import torch.onnx as onnx

# %%
train_path = r"E:\Datasets\Glaucoma_detection\Fundus_Train_Val_Data\Fundus_Scanes_Sorted_And_Cropped_v2\Train"
test_path  = r"E:\Datasets\Glaucoma_detection\Fundus_Train_Val_Data\Fundus_Scanes_Sorted_And_Cropped_v2\Validation"

# %%
# определим объект трансформации изображений
no_aug_transform = transforms.Compose(
      [
            transforms.Resize(size=(224, 224)),
            transforms.ToTensor(),
      ]
)

# %%
test_data = dataset.ImageFolder(test_path, no_aug_transform)

print(type(test_data))

print(test_data.classes)
# Out:
# <class 'torchvision.datasets.folder.ImageFolder'>
# ['Glaucoma_Negative', 'Glaucoma_Positive']

# %%
print(test_data[0][0])
# Out:
# tensor([[[0.8784, 0.8706, 0.8667,  ..., 0.8667, 0.8745, 0.8706],
#          [0.8784, 0.8745, 0.8745,  ..., 0.8667, 0.8745, 0.8784],
#          [0.8784, 0.8745, 0.8706,  ..., 0.8667, 0.8745, 0.8745],
#          ...,
#          [0.8353, 0.8235, 0.8157,  ..., 0.8863, 0.8824, 0.8784],
#          [0.8314, 0.8196, 0.8196,  ..., 0.8902, 0.8863, 0.8824],
#          [0.8314, 0.8275, 0.8275,  ..., 0.8941, 0.8902, 0.8902]],
#
#         [[0.5373, 0.5333, 0.5373,  ..., 0.5569, 0.5647, 0.5608],
#          [0.5412, 0.5412, 0.5451,  ..., 0.5569, 0.5647, 0.5686],
#          [0.5412, 0.5412, 0.5451,  ..., 0.5569, 0.5647, 0.5647],
#          ...,
#          [0.4863, 0.4745, 0.4627,  ..., 0.5373, 0.5255, 0.5216],
#          [0.4824, 0.4706, 0.4667,  ..., 0.5373, 0.5294, 0.5255],
#          [0.4824, 0.4745, 0.4745,  ..., 0.5373, 0.5333, 0.5333]],
#
#         [[0.1961, 0.1922, 0.2000,  ..., 0.1922, 0.2000, 0.1961],
#          [0.2000, 0.1961, 0.2078,  ..., 0.1922, 0.2000, 0.2039],
#          [0.2000, 0.1961, 0.2078,  ..., 0.1922, 0.2000, 0.2000],
#          ...,
#          [0.1725, 0.1608, 0.1569,  ..., 0.1765, 0.1686, 0.1647],
#          [0.1686, 0.1608, 0.1608,  ..., 0.1765, 0.1725, 0.1686],
#          [0.1725, 0.1686, 0.1686,  ..., 0.1804, 0.1765, 0.1765]]])

# %%
# определим устройство, на котором будет идти обучение
device = None
if torch.cuda.is_available():
    device = torch.device("cuda")
else:
    device = torch.device("cpu")

# %%
state_dict = torch.load(r"..\..\src\weights\classification\pytorch\efficientnetb0_best_checkpoint_crop_optic_disc.pth", map_location=device).state_dict()
inference_model = models.efficientnet_b0(num_classes=2, pretrained=False)
inference_model.load_state_dict(state_dict)
inference_model.eval()
inference_model.to(device)
# Out:
# EfficientNet(
#   (features): Sequential(
#     (0): Conv2dNormActivation(
#       (0): Conv2d(3, 32, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#       (1): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (2): SiLU(inplace=True)
#     )
#     (1): Sequential(
#       (0): MBConv(
#         (block): Sequential(
#           (0): Conv2dNormActivation(
#             (0): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=32, bias=False)
#             (1): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (2): SiLU(inplace=True)
#           )
#           (1): SqueezeExcitation(
#             (avgpool): AdaptiveAvgPool2d(output_size=1)
#             (fc1): Conv2d(32, 8, kernel_size=(1, 1), stride=(1, 1))
#             (fc2): Conv2d(8, 32, kernel_size=(1, 1), stride=(1, 1))
#             (activation): SiLU(inplace=True)
#             (scale_activation): Sigmoid()
#           )
#           (2): Conv2dNormActivation(
#             (0): Conv2d(32, 16, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           )
#         )
#         (stochastic_depth): StochasticDepth(p=0.0, mode=row)
#       )
#     )
#     (2): Sequential(
#       (0): MBConv(
#         (block): Sequential(
#           (0): Conv2dNormActivation(
#             (0): Conv2d(16, 96, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(96, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (2): SiLU(inplace=True)
#           )
#           (1): Conv2dNormActivation(
#             (0): Conv2d(96, 96, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), groups=96, bias=False)
#             (1): BatchNorm2d(96, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (2): SiLU(inplace=True)
#           )
#           (2): SqueezeExcitation(
#             (avgpool): AdaptiveAvgPool2d(output_size=1)
#             (fc1): Conv2d(96, 4, kernel_size=(1, 1), stride=(1, 1))
#             (fc2): Conv2d(4, 96, kernel_size=(1, 1), stride=(1, 1))
#             (activation): SiLU(inplace=True)
#             (scale_activation): Sigmoid()
#           )
#           (3): Conv2dNormActivation(
#             (0): Conv2d(96, 24, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(24, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           )
#         )
#         (stochastic_depth): StochasticDepth(p=0.0125, mode=row)
#       )
#       (1): MBConv(
#         (block): Sequential(
#           (0): Conv2dNormActivation(
#             (0): Conv2d(24, 144, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(144, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (2): SiLU(inplace=True)
#           )
#           (1): Conv2dNormActivation(
#             (0): Conv2d(144, 144, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=144, bias=False)
#             (1): BatchNorm2d(144, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (2): SiLU(inplace=True)
#           )
#           (2): SqueezeExcitation(
#             (avgpool): AdaptiveAvgPool2d(output_size=1)
#             (fc1): Conv2d(144, 6, kernel_size=(1, 1), stride=(1, 1))
#             (fc2): Conv2d(6, 144, kernel_size=(1, 1), stride=(1, 1))
#             (activation): SiLU(inplace=True)
#             (scale_activation): Sigmoid()
#           )
#           (3): Conv2dNormActivation(
#             (0): Conv2d(144, 24, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(24, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           )
#         )
#         (stochastic_depth): StochasticDepth(p=0.025, mode=row)
#       )
#     )
#     (3): Sequential(
#       (0): MBConv(
#         (block): Sequential(
#           (0): Conv2dNormActivation(
#             (0): Conv2d(24, 144, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(144, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (2): SiLU(inplace=True)
#           )
#           (1): Conv2dNormActivation(
#             (0): Conv2d(144, 144, kernel_size=(5, 5), stride=(2, 2), padding=(2, 2), groups=144, bias=False)
#             (1): BatchNorm2d(144, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (2): SiLU(inplace=True)
#           )
#           (2): SqueezeExcitation(
#             (avgpool): AdaptiveAvgPool2d(output_size=1)
#             (fc1): Conv2d(144, 6, kernel_size=(1, 1), stride=(1, 1))
#             (fc2): Conv2d(6, 144, kernel_size=(1, 1), stride=(1, 1))
#             (activation): SiLU(inplace=True)
#             (scale_activation): Sigmoid()
#           )
#           (3): Conv2dNormActivation(
#             (0): Conv2d(144, 40, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(40, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           )
#         )
#         (stochastic_depth): StochasticDepth(p=0.037500000000000006, mode=row)
#       )
#       (1): MBConv(
#         (block): Sequential(
#           (0): Conv2dNormActivation(
#             (0): Conv2d(40, 240, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(240, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (2): SiLU(inplace=True)
#           )
#           (1): Conv2dNormActivation(
#             (0): Conv2d(240, 240, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2), groups=240, bias=False)
#             (1): BatchNorm2d(240, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (2): SiLU(inplace=True)
#           )
#           (2): SqueezeExcitation(
#             (avgpool): AdaptiveAvgPool2d(output_size=1)
#             (fc1): Conv2d(240, 10, kernel_size=(1, 1), stride=(1, 1))
#             (fc2): Conv2d(10, 240, kernel_size=(1, 1), stride=(1, 1))
#             (activation): SiLU(inplace=True)
#             (scale_activation): Sigmoid()
#           )
#           (3): Conv2dNormActivation(
#             (0): Conv2d(240, 40, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(40, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           )
#         )
#         (stochastic_depth): StochasticDepth(p=0.05, mode=row)
#       )
#     )
#     (4): Sequential(
#       (0): MBConv(
#         (block): Sequential(
#           (0): Conv2dNormActivation(
#             (0): Conv2d(40, 240, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(240, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (2): SiLU(inplace=True)
#           )
#           (1): Conv2dNormActivation(
#             (0): Conv2d(240, 240, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), groups=240, bias=False)
#             (1): BatchNorm2d(240, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (2): SiLU(inplace=True)
#           )
#           (2): SqueezeExcitation(
#             (avgpool): AdaptiveAvgPool2d(output_size=1)
#             (fc1): Conv2d(240, 10, kernel_size=(1, 1), stride=(1, 1))
#             (fc2): Conv2d(10, 240, kernel_size=(1, 1), stride=(1, 1))
#             (activation): SiLU(inplace=True)
#             (scale_activation): Sigmoid()
#           )
#           (3): Conv2dNormActivation(
#             (0): Conv2d(240, 80, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(80, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           )
#         )
#         (stochastic_depth): StochasticDepth(p=0.0625, mode=row)
#       )
#       (1): MBConv(
#         (block): Sequential(
#           (0): Conv2dNormActivation(
#             (0): Conv2d(80, 480, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(480, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (2): SiLU(inplace=True)
#           )
#           (1): Conv2dNormActivation(
#             (0): Conv2d(480, 480, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=480, bias=False)
#             (1): BatchNorm2d(480, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (2): SiLU(inplace=True)
#           )
#           (2): SqueezeExcitation(
#             (avgpool): AdaptiveAvgPool2d(output_size=1)
#             (fc1): Conv2d(480, 20, kernel_size=(1, 1), stride=(1, 1))
#             (fc2): Conv2d(20, 480, kernel_size=(1, 1), stride=(1, 1))
#             (activation): SiLU(inplace=True)
#             (scale_activation): Sigmoid()
#           )
#           (3): Conv2dNormActivation(
#             (0): Conv2d(480, 80, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(80, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           )
#         )
#         (stochastic_depth): StochasticDepth(p=0.07500000000000001, mode=row)
#       )
#       (2): MBConv(
#         (block): Sequential(
#           (0): Conv2dNormActivation(
#             (0): Conv2d(80, 480, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(480, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (2): SiLU(inplace=True)
#           )
#           (1): Conv2dNormActivation(
#             (0): Conv2d(480, 480, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=480, bias=False)
#             (1): BatchNorm2d(480, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (2): SiLU(inplace=True)
#           )
#           (2): SqueezeExcitation(
#             (avgpool): AdaptiveAvgPool2d(output_size=1)
#             (fc1): Conv2d(480, 20, kernel_size=(1, 1), stride=(1, 1))
#             (fc2): Conv2d(20, 480, kernel_size=(1, 1), stride=(1, 1))
#             (activation): SiLU(inplace=True)
#             (scale_activation): Sigmoid()
#           )
#           (3): Conv2dNormActivation(
#             (0): Conv2d(480, 80, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(80, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           )
#         )
#         (stochastic_depth): StochasticDepth(p=0.08750000000000001, mode=row)
#       )
#     )
#     (5): Sequential(
#       (0): MBConv(
#         (block): Sequential(
#           (0): Conv2dNormActivation(
#             (0): Conv2d(80, 480, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(480, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (2): SiLU(inplace=True)
#           )
#           (1): Conv2dNormActivation(
#             (0): Conv2d(480, 480, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2), groups=480, bias=False)
#             (1): BatchNorm2d(480, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (2): SiLU(inplace=True)
#           )
#           (2): SqueezeExcitation(
#             (avgpool): AdaptiveAvgPool2d(output_size=1)
#             (fc1): Conv2d(480, 20, kernel_size=(1, 1), stride=(1, 1))
#             (fc2): Conv2d(20, 480, kernel_size=(1, 1), stride=(1, 1))
#             (activation): SiLU(inplace=True)
#             (scale_activation): Sigmoid()
#           )
#           (3): Conv2dNormActivation(
#             (0): Conv2d(480, 112, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(112, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           )
#         )
#         (stochastic_depth): StochasticDepth(p=0.1, mode=row)
#       )
#       (1): MBConv(
#         (block): Sequential(
#           (0): Conv2dNormActivation(
#             (0): Conv2d(112, 672, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(672, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (2): SiLU(inplace=True)
#           )
#           (1): Conv2dNormActivation(
#             (0): Conv2d(672, 672, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2), groups=672, bias=False)
#             (1): BatchNorm2d(672, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (2): SiLU(inplace=True)
#           )
#           (2): SqueezeExcitation(
#             (avgpool): AdaptiveAvgPool2d(output_size=1)
#             (fc1): Conv2d(672, 28, kernel_size=(1, 1), stride=(1, 1))
#             (fc2): Conv2d(28, 672, kernel_size=(1, 1), stride=(1, 1))
#             (activation): SiLU(inplace=True)
#             (scale_activation): Sigmoid()
#           )
#           (3): Conv2dNormActivation(
#             (0): Conv2d(672, 112, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(112, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           )
#         )
#         (stochastic_depth): StochasticDepth(p=0.1125, mode=row)
#       )
#       (2): MBConv(
#         (block): Sequential(
#           (0): Conv2dNormActivation(
#             (0): Conv2d(112, 672, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(672, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (2): SiLU(inplace=True)
#           )
#           (1): Conv2dNormActivation(
#             (0): Conv2d(672, 672, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2), groups=672, bias=False)
#             (1): BatchNorm2d(672, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (2): SiLU(inplace=True)
#           )
#           (2): SqueezeExcitation(
#             (avgpool): AdaptiveAvgPool2d(output_size=1)
#             (fc1): Conv2d(672, 28, kernel_size=(1, 1), stride=(1, 1))
#             (fc2): Conv2d(28, 672, kernel_size=(1, 1), stride=(1, 1))
#             (activation): SiLU(inplace=True)
#             (scale_activation): Sigmoid()
#           )
#           (3): Conv2dNormActivation(
#             (0): Conv2d(672, 112, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(112, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           )
#         )
#         (stochastic_depth): StochasticDepth(p=0.125, mode=row)
#       )
#     )
#     (6): Sequential(
#       (0): MBConv(
#         (block): Sequential(
#           (0): Conv2dNormActivation(
#             (0): Conv2d(112, 672, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(672, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (2): SiLU(inplace=True)
#           )
#           (1): Conv2dNormActivation(
#             (0): Conv2d(672, 672, kernel_size=(5, 5), stride=(2, 2), padding=(2, 2), groups=672, bias=False)
#             (1): BatchNorm2d(672, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (2): SiLU(inplace=True)
#           )
#           (2): SqueezeExcitation(
#             (avgpool): AdaptiveAvgPool2d(output_size=1)
#             (fc1): Conv2d(672, 28, kernel_size=(1, 1), stride=(1, 1))
#             (fc2): Conv2d(28, 672, kernel_size=(1, 1), stride=(1, 1))
#             (activation): SiLU(inplace=True)
#             (scale_activation): Sigmoid()
#           )
#           (3): Conv2dNormActivation(
#             (0): Conv2d(672, 192, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(192, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           )
#         )
#         (stochastic_depth): StochasticDepth(p=0.1375, mode=row)
#       )
#       (1): MBConv(
#         (block): Sequential(
#           (0): Conv2dNormActivation(
#             (0): Conv2d(192, 1152, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(1152, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (2): SiLU(inplace=True)
#           )
#           (1): Conv2dNormActivation(
#             (0): Conv2d(1152, 1152, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2), groups=1152, bias=False)
#             (1): BatchNorm2d(1152, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (2): SiLU(inplace=True)
#           )
#           (2): SqueezeExcitation(
#             (avgpool): AdaptiveAvgPool2d(output_size=1)
#             (fc1): Conv2d(1152, 48, kernel_size=(1, 1), stride=(1, 1))
#             (fc2): Conv2d(48, 1152, kernel_size=(1, 1), stride=(1, 1))
#             (activation): SiLU(inplace=True)
#             (scale_activation): Sigmoid()
#           )
#           (3): Conv2dNormActivation(
#             (0): Conv2d(1152, 192, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(192, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           )
#         )
#         (stochastic_depth): StochasticDepth(p=0.15000000000000002, mode=row)
#       )
#       (2): MBConv(
#         (block): Sequential(
#           (0): Conv2dNormActivation(
#             (0): Conv2d(192, 1152, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(1152, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (2): SiLU(inplace=True)
#           )
#           (1): Conv2dNormActivation(
#             (0): Conv2d(1152, 1152, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2), groups=1152, bias=False)
#             (1): BatchNorm2d(1152, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (2): SiLU(inplace=True)
#           )
#           (2): SqueezeExcitation(
#             (avgpool): AdaptiveAvgPool2d(output_size=1)
#             (fc1): Conv2d(1152, 48, kernel_size=(1, 1), stride=(1, 1))
#             (fc2): Conv2d(48, 1152, kernel_size=(1, 1), stride=(1, 1))
#             (activation): SiLU(inplace=True)
#             (scale_activation): Sigmoid()
#           )
#           (3): Conv2dNormActivation(
#             (0): Conv2d(1152, 192, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(192, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           )
#         )
#         (stochastic_depth): StochasticDepth(p=0.1625, mode=row)
#       )
#       (3): MBConv(
#         (block): Sequential(
#           (0): Conv2dNormActivation(
#             (0): Conv2d(192, 1152, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(1152, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (2): SiLU(inplace=True)
#           )
#           (1): Conv2dNormActivation(
#             (0): Conv2d(1152, 1152, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2), groups=1152, bias=False)
#             (1): BatchNorm2d(1152, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (2): SiLU(inplace=True)
#           )
#           (2): SqueezeExcitation(
#             (avgpool): AdaptiveAvgPool2d(output_size=1)
#             (fc1): Conv2d(1152, 48, kernel_size=(1, 1), stride=(1, 1))
#             (fc2): Conv2d(48, 1152, kernel_size=(1, 1), stride=(1, 1))
#             (activation): SiLU(inplace=True)
#             (scale_activation): Sigmoid()
#           )
#           (3): Conv2dNormActivation(
#             (0): Conv2d(1152, 192, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(192, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           )
#         )
#         (stochastic_depth): StochasticDepth(p=0.17500000000000002, mode=row)
#       )
#     )
#     (7): Sequential(
#       (0): MBConv(
#         (block): Sequential(
#           (0): Conv2dNormActivation(
#             (0): Conv2d(192, 1152, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(1152, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (2): SiLU(inplace=True)
#           )
#           (1): Conv2dNormActivation(
#             (0): Conv2d(1152, 1152, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=1152, bias=False)
#             (1): BatchNorm2d(1152, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (2): SiLU(inplace=True)
#           )
#           (2): SqueezeExcitation(
#             (avgpool): AdaptiveAvgPool2d(output_size=1)
#             (fc1): Conv2d(1152, 48, kernel_size=(1, 1), stride=(1, 1))
#             (fc2): Conv2d(48, 1152, kernel_size=(1, 1), stride=(1, 1))
#             (activation): SiLU(inplace=True)
#             (scale_activation): Sigmoid()
#           )
#           (3): Conv2dNormActivation(
#             (0): Conv2d(1152, 320, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(320, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           )
#         )
#         (stochastic_depth): StochasticDepth(p=0.1875, mode=row)
#       )
#     )
#     (8): Conv2dNormActivation(
#       (0): Conv2d(320, 1280, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (1): BatchNorm2d(1280, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (2): SiLU(inplace=True)
#     )
#   )
#   (avgpool): AdaptiveAvgPool2d(output_size=1)
#   (classifier): Sequential(
#     (0): Dropout(p=0.2, inplace=True)
#     (1): Linear(in_features=1280, out_features=2, bias=True)
#   )
# )

# %%
# создаем входной тензор модели
x = torch.randn(1, 3, 224, 224, requires_grad=True).to(device)

# сгенерируем выходы модели
out = inference_model(x)

# экспортируем модель в onnx
onnx.export(inference_model, x, r"..\..\src\weights\classification\onnx\efficientnetb0_best_checkpoint_crop_optic_disc.onnx", input_names=["image"], output_names=["output"], )

# %%
import onnx

onnx_model = onnx.load( r"..\..\src\weights\classification\onnx\efficientnetb0_best_checkpoint_crop_optic_disc.onnx")
onnx.checker.check_model(onnx_model)

# %%
# инициализируем сессию  ONNXRuntime
ort_session = onnxruntime.InferenceSession(r"..\..\src\weights\classification\onnx\efficientnetb0_best_checkpoint_crop_optic_disc.onnx", providers=["CPUExecutionProvider" if device == "cpu" else "CUDAExecutionProvider"])

# определим функцию перевода тензора в numpy-массив
def to_numpy(tensor):
    return tensor.detach().cpu().numpy() if tensor.requires_grad else tensor.cpu().numpy()

# определим входы и выходы 
ort_inputs = {ort_session.get_inputs()[0].name: to_numpy(x)}
ort_outs = ort_session.run(None, ort_inputs)
print(ort_outs)
print(out)

# сравним результаты
np.testing.assert_allclose(to_numpy(out[0]), ort_outs[0][0], rtol=2e-02, atol=1e-03)
print("Все хорошо!")
# Out:
# [array([[-0.91505665,  4.8708334 ]], dtype=float32)]
# tensor([[-0.9145,  4.8683]], device='cuda:0', grad_fn=<AddmmBackward0>)
# Все хорошо!

# %%
EFFICIENTNET_INPUT_WIDTH = ort_session.get_inputs()[0].shape[2]
EFFICIENTNET_INPUT_HEIGHT = ort_session.get_inputs()[0].shape[3]
EFFICIENTNET_INPUT_CHANNELS = ort_session.get_inputs()[0].shape[1]

# %%
# mixed cv2 and PIL preprocess
import cv2
from PIL import Image
import shutil

total_images_count = 0
true_classified_images_count = 0

test_listdir = os.listdir(test_path)
for class_name in test_listdir:
    images_listdir = os.listdir(os.path.join(test_path, class_name))
    for i, image in enumerate(images_listdir):
        path_to_image = os.path.join(test_path, class_name, image)
        print(path_to_image)
        image_array_ = cv2.imdecode(np.fromfile(path_to_image, dtype=np.uint8), cv2.IMREAD_UNCHANGED)
        image_array = np.array(Image.fromarray(image_array_).resize((EFFICIENTNET_INPUT_WIDTH, EFFICIENTNET_INPUT_HEIGHT), Image.BILINEAR))
        image_array = image_array.transpose(2, 0, 1)
        image_array = np.expand_dims(image_array, axis=(0))
        outputs = ort_session.run(None, {ort_session.get_inputs()[0].name: image_array.astype("float32")})
        preds_id = outputs[0].argmax()
        class_name_pred = test_data.classes[preds_id]
        if class_name == class_name_pred:
            true_classified_images_count += 1
        else:
            print("\n" + f"label {class_name}, predicted {class_name_pred}")
        total_images_count += 1
# Out:
# E:\Datasets\Glaucoma_detection\Fundus_Train_Val_Data\Fundus_Scanes_Sorted_And_Cropped_v2\Validation\Glaucoma_Negative\483.jpg
# E:\Datasets\Glaucoma_detection\Fundus_Train_Val_Data\Fundus_Scanes_Sorted_And_Cropped_v2\Validation\Glaucoma_Negative\484.jpg
# E:\Datasets\Glaucoma_detection\Fundus_Train_Val_Data\Fundus_Scanes_Sorted_And_Cropped_v2\Validation\Glaucoma_Negative\485.jpg
# E:\Datasets\Glaucoma_detection\Fundus_Train_Val_Data\Fundus_Scanes_Sorted_And_Cropped_v2\Validation\Glaucoma_Negative\487.jpg
# E:\Datasets\Glaucoma_detection\Fundus_Train_Val_Data\Fundus_Scanes_Sorted_And_Cropped_v2\Validation\Glaucoma_Negative\488.jpg
# E:\Datasets\Glaucoma_detection\Fundus_Train_Val_Data\Fundus_Scanes_Sorted_And_Cropped_v2\Validation\Glaucoma_Negative\489.jpg
# E:\Datasets\Glaucoma_detection\Fundus_Train_Val_Data\Fundus_Scanes_Sorted_And_Cropped_v2\Validation\Glaucoma_Negative\491.jpg
# E:\Datasets\Glaucoma_detection\Fundus_Train_Val_Data\Fundus_Scanes_Sorted_And_Cropped_v2\Validation\Glaucoma_Negative\492.jpg
# E:\Datasets\Glaucoma_detection\Fundus_Train_Val_Data\Fundus_Scanes_Sorted_And_Cropped_v2\Validation\Glaucoma_Negative\493.jpg
# E:\Datasets\Glaucoma_detection\Fundus_Train_Val_Data\Fundus_Scanes_Sorted_And_Cropped_v2\Validation\Glaucoma_Negative\494.jpg
# E:\Datasets\Glaucoma_detection\Fundus_Train_Val_Data\Fundus_Scanes_Sorted_And_Cropped_v2\Validation\Glaucoma_Negative\495.jpg
# E:\Datasets\Glaucoma_detection\Fundus_Train_Val_Data\Fundus_Scanes_Sorted_And_Cropped_v2\Validation\Glaucoma_Negative\497.jpg
# E:\Datasets\Glaucoma_detection\Fundus_Train_Val_Data\Fundus_Scanes_Sorted_And_Cropped_v2\Validation\Glaucoma_Negative\498.jpg
# E:\Datasets\Glaucoma_detection\Fundus_Train_Val_Data\Fundus_Scanes_Sorted_And_Cropped_v2\Validation\Glaucoma_Negative\499.jpg
# E:\Datasets\Glaucoma_detection\Fundus_Train_Val_Data\Fundus_Scanes_Sorted_And_Cropped_v2\Validation\Glaucoma_Negative\500.jpg
# E:\Datasets\Glaucoma_detection\Fundus_Train_Val_Data\Fundus_Scanes_Sorted_And_Cropped_v2\Validation\Glaucoma_Negative\501.jpg
# E:\Datasets\Glaucoma_detection\Fundus_Train_Val_Data\Fundus_Scanes_Sorted_And_Cropped_v2\Validation\Glaucoma_Negative\502.jpg
# E:\Datasets\Glaucoma_detection\Fundus_Train_Val_Data\Fundus_Scanes_Sorted_And_Cropped_v2\Validation\Glaucoma_Negative\503.jpg
# E:\Datasets\Glaucoma_detection\Fundus_Train_Val_Data\Fundus_Scanes_Sorted_And_Cropped_v2\Validation\Glaucoma_Negative\504.jpg
# E:\Datasets\Glaucoma_detection\Fundus_Train_Val_Data\Fundus_Scanes_Sorted_And_Cropped_v2\Validation\Glaucoma_Negative\509.jpg
# E:\Datasets\Glaucoma_detection\Fundus_Train_Val_Data\Fundus_Scanes_Sorted_And_Cropped_v2\Validation\Glaucoma_Negative\510.jpg
# E:\Datasets\Glaucoma_detection\Fundus_Train_Val_Data\Fundus_Scanes_Sorted_And_Cropped_v2\Validation\Glaucoma_Negative\513.jpg
# E:\Datasets\Glaucoma_detection\Fundus_Train_Val_Data\Fundus_Scanes_Sorted_And_Cropped_v2\Validation\Glaucoma_Negative\517.jpg
# E:\Datasets\Glaucoma_detection\Fundus_Train_Val_Data\Fundus_Scanes_Sorted_And_Cropped_v2\Validation\Glaucoma_Negative\518.jpg
# E:\Datasets\Glaucoma_detection\Fundus_Train_Val_Data\Fundus_Scanes_Sorted_And_Cropped_v2\Validation\Glaucoma_Negative\520.jpg
# E:\Datasets\Glaucoma_detection\Fundus_Train_Val_Data\Fundus_Scanes_Sorted_And_Cropped_v2\Validation\Glaucoma_Negative\521.jpg
# E:\Datasets\Glaucoma_detection\Fundus_Train_Val_Data\Fundus_Scanes_Sorted_And_Cropped_v2\Validation\Glaucoma_Negative\522.jpg
# E:\Datasets\Glaucoma_detection\Fundus_Train_Val_Data\Fundus_Scanes_Sorted_And_Cropped_v2\Validation\Glaucoma_Negative\525.jpg
# E:\Datasets\Glaucoma_detection\Fundus_Train_Val_Data\Fundus_Scanes_Sorted_And_Cropped_v2\Validation\Glaucoma_Negative\526.jpg
# E:\Datasets\Glaucoma_detection\Fundus_Train_Val_Data\Fundus_Scanes_Sorted_And_Cropped_v2\Validation\Glaucoma_Negative\527.jpg
# E:\Datasets\Glaucoma_detection\Fundus_Train_Val_Data\Fundus_Scanes_Sorted_And_Cropped_v2\Validation\Glaucoma_Negative\529.jpg
# E:\Datasets\Glaucoma_detection\Fundus_Train_Val_Data\Fundus_Scanes_Sorted_And_Cropped_v2\Validation\Glaucoma_Negative\530.jpg
# E:\Datasets\Glaucoma_detection\Fundus_Train_Val_Data\Fundus_Scanes_Sorted_And_Cropped_v2\Validation\Glaucoma_Negative\531.jpg
# E:\Datasets\Glaucoma_detection\Fundus_Train_Val_Data\Fundus_Scanes_Sorted_And_Cropped_v2\Validation\Glaucoma_Negative\534.jpg
# E:\Datasets\Glaucoma_detection\Fundus_Train_Val_Data\Fundus_Scanes_Sorted_And_Cropped_v2\Validation\Glaucoma_Negative\535.jpg
# E:\Datasets\Glaucoma_detection\Fundus_Train_Val_Data\Fundus_Scanes_Sorted_And_Cropped_v2\Validation\Glaucoma_Negative\536.jpg
# E:\Datasets\Glaucoma_detection\Fundus_Train_Val_Data\Fundus_Scanes_Sorted_And_Cropped_v2\Validation\Glaucoma_Negative\537.jpg
# E:\Datasets\Glaucoma_detection\Fundus_Train_Val_Data\Fundus_Scanes_Sorted_And_Cropped_v2\Validation\Glaucoma_Negative\538.jpg
# E:\Datasets\Glaucoma_detection\Fundus_Train_Val_Data\Fundus_Scanes_Sorted_And_Cropped_v2\Validation\Glaucoma_Negative\539.jpg
# E:\Datasets\Glaucoma_detection\Fundus_Train_Val_Data\Fundus_Scanes_Sorted_And_Cropped_v2\Validation\Glaucoma_Negative\540.jpg
# E:\Datasets\Glaucoma_detection\Fundus_Train_Val_Data\Fundus_Scanes_Sorted_And_Cropped_v2\Validation\Glaucoma_Negative\541.jpg
# E:\Datasets\Glaucoma_detection\Fundus_Train_Val_Data\Fundus_Scanes_Sorted_And_Cropped_v2\Validation\Glaucoma_Negative\542.jpg
# E:\Datasets\Glaucoma_detection\Fundus_Train_Val_Data\Fundus_Scanes_Sorted_And_Cropped_v2\Validation\Glaucoma_Negative\543.jpg
# E:\Datasets\Glaucoma_detection\Fundus_Train_Val_Data\Fundus_Scanes_Sorted_And_Cropped_v2\Validation\Glaucoma_Negative\544.jpg
# E:\Datasets\Glaucoma_detection\Fundus_Train_Val_Data\Fundus_Scanes_Sorted_And_Cropped_v2\Validation\Glaucoma_Negative\546.jpg
# E:\Datasets\Glaucoma_detection\Fundus_Train_Val_Data\Fundus_Scanes_Sorted_And_Cropped_v2\Validation\Glaucoma_Negative\547.jpg
# E:\Datasets\Glaucoma_detection\Fundus_Train_Val_Data\Fundus_Scanes_Sorted_And_Cropped_v2\Validation\Glaucoma_Negative\548.jpg
# E:\Datasets\Glaucoma_detection\Fundus_Train_Val_Data\Fundus_Scanes_Sorted_And_Cropped_v2\Validation\Glaucoma_Negative\551.jpg
# E:\Datasets\Glaucoma_detection\Fundus_Train_Val_Data\Fundus_Scanes_Sorted_And_Cropped_v2\Validation\Glaucoma_Negative\552.jpg
# E:\Datasets\Glaucoma_detection\Fundus_Train_Val_Data\Fundus_Scanes_Sorted_And_Cropped_v2\Validation\Glaucoma_Negative\553.jpg
# E:\Datasets\Glaucoma_detection\Fundus_Train_Val_Data\Fundus_Scanes_Sorted_And_Cropped_v2\Validation\Glaucoma_Negative\554.jpg
# E:\Datasets\Glaucoma_detection\Fundus_Train_Val_Data\Fundus_Scanes_Sorted_And_Cropped_v2\Validation\Glaucoma_Negative\555.jpg
# E:\Datasets\Glaucoma_detection\Fundus_Train_Val_Data\Fundus_Scanes_Sorted_And_Cropped_v2\Validation\Glaucoma_Negative\559.jpg
# E:\Datasets\Glaucoma_detection\Fundus_Train_Val_Data\Fundus_Scanes_Sorted_And_Cropped_v2\Validation\Glaucoma_Negative\561.jpg
# E:\Datasets\Glaucoma_detection\Fundus_Train_Val_Data\Fundus_Scanes_Sorted_And_Cropped_v2\Validation\Glaucoma_Negative\562.jpg
# E:\Datasets\Glaucoma_detection\Fundus_Train_Val_Data\Fundus_Scanes_Sorted_And_Cropped_v2\Validation\Glaucoma_Negative\563.jpg
# E:\Datasets\Glaucoma_detection\Fundus_Train_Val_Data\Fundus_Scanes_Sorted_And_Cropped_v2\Validation\Glaucoma_Negative\564.jpg
# E:\Datasets\Glaucoma_detection\Fundus_Train_Val_Data\Fundus_Scanes_Sorted_And_Cropped_v2\Validation\Glaucoma_Negative\565.jpg
# E:\Datasets\Glaucoma_detection\Fundus_Train_Val_Data\Fundus_Scanes_Sorted_And_Cropped_v2\Validation\Glaucoma_Negative\566.jpg
# E:\Datasets\Glaucoma_detection\Fundus_Train_Val_Data\Fundus_Scanes_Sorted_And_Cropped_v2\Validation\Glaucoma_Negative\567.jpg
# E:\Datasets\Glaucoma_detection\Fundus_Train_Val_Data\Fundus_Scanes_Sorted_And_Cropped_v2\Validation\Glaucoma_Negative\568.jpg
# E:\Datasets\Glaucoma_detection\Fundus_Train_Val_Data\Fundus_Scanes_Sorted_And_Cropped_v2\Validation\Glaucoma_Negative\569.jpg
# E:\Datasets\Glaucoma_detection\Fundus_Train_Val_Data\Fundus_Scanes_Sorted_And_Cropped_v2\Validation\Glaucoma_Negative\570.jpg
# E:\Datasets\Glaucoma_detection\Fundus_Train_Val_Data\Fundus_Scanes_Sorted_And_Cropped_v2\Validation\Glaucoma_Negative\573.jpg
# E:\Datasets\Glaucoma_detection\Fundus_Train_Val_Data\Fundus_Scanes_Sorted_And_Cropped_v2\Validation\Glaucoma_Negative\574.jpg
# E:\Datasets\Glaucoma_detection\Fundus_Train_Val_Data\Fundus_Scanes_Sorted_And_Cropped_v2\Validation\Glaucoma_Negative\575.jpg
# E:\Datasets\Glaucoma_detection\Fundus_Train_Val_Data\Fundus_Scanes_Sorted_And_Cropped_v2\Validation\Glaucoma_Negative\576.jpg
# E:\Datasets\Glaucoma_detection\Fundus_Train_Val_Data\Fundus_Scanes_Sorted_And_Cropped_v2\Validation\Glaucoma_Negative\577.jpg
# E:\Datasets\Glaucoma_detection\Fundus_Train_Val_Data\Fundus_Scanes_Sorted_And_Cropped_v2\Validation\Glaucoma_Negative\579.jpg
# E:\Datasets\Glaucoma_detection\Fundus_Train_Val_Data\Fundus_Scanes_Sorted_And_Cropped_v2\Validation\Glaucoma_Negative\581.jpg
# E:\Datasets\Glaucoma_detection\Fundus_Train_Val_Data\Fundus_Scanes_Sorted_And_Cropped_v2\Validation\Glaucoma_Negative\583.jpg
# E:\Datasets\Glaucoma_detection\Fundus_Train_Val_Data\Fundus_Scanes_Sorted_And_Cropped_v2\Validation\Glaucoma_Negative\585.jpg
# E:\Datasets\Glaucoma_detection\Fundus_Train_Val_Data\Fundus_Scanes_Sorted_And_Cropped_v2\Validation\Glaucoma_Negative\587.jpg
# E:\Datasets\Glaucoma_detection\Fundus_Train_Val_Data\Fundus_Scanes_Sorted_And_Cropped_v2\Validation\Glaucoma_Negative\590.jpg
# E:\Datasets\Glaucoma_detection\Fundus_Train_Val_Data\Fundus_Scanes_Sorted_And_Cropped_v2\Validation\Glaucoma_Negative\594.jpg
# E:\Datasets\Glaucoma_detection\Fundus_Train_Val_Data\Fundus_Scanes_Sorted_And_Cropped_v2\Validation\Glaucoma_Negative\596.jpg
# E:\Datasets\Glaucoma_detection\Fundus_Train_Val_Data\Fundus_Scanes_Sorted_And_Cropped_v2\Validation\Glaucoma_Negative\597.jpg
# E:\Datasets\Glaucoma_detection\Fundus_Train_Val_Data\Fundus_Scanes_Sorted_And_Cropped_v2\Validation\Glaucoma_Negative\599.jpg
# E:\Datasets\Glaucoma_detection\Fundus_Train_Val_Data\Fundus_Scanes_Sorted_And_Cropped_v2\Validation\Glaucoma_Negative\602.jpg
# E:\Datasets\Glaucoma_detection\Fundus_Train_Val_Data\Fundus_Scanes_Sorted_And_Cropped_v2\Validation\Glaucoma_Negative\603.jpg
# E:\Datasets\Glaucoma_detection\Fundus_Train_Val_Data\Fundus_Scanes_Sorted_And_Cropped_v2\Validation\Glaucoma_Negative\606.jpg
# E:\Datasets\Glaucoma_detection\Fundus_Train_Val_Data\Fundus_Scanes_Sorted_And_Cropped_v2\Validation\Glaucoma_Negative\607.jpg
# E:\Datasets\Glaucoma_detection\Fundus_Train_Val_Data\Fundus_Scanes_Sorted_And_Cropped_v2\Validation\Glaucoma_Negative\610.jpg
# E:\Datasets\Glaucoma_detection\Fundus_Train_Val_Data\Fundus_Scanes_Sorted_And_Cropped_v2\Validation\Glaucoma_Negative\611.jpg
# E:\Datasets\Glaucoma_detection\Fundus_Train_Val_Data\Fundus_Scanes_Sorted_And_Cropped_v2\Validation\Glaucoma_Negative\614.jpg
# E:\Datasets\Glaucoma_detection\Fundus_Train_Val_Data\Fundus_Scanes_Sorted_And_Cropped_v2\Validation\Glaucoma_Negative\616.jpg
# E:\Datasets\Glaucoma_detection\Fundus_Train_Val_Data\Fundus_Scanes_Sorted_And_Cropped_v2\Validation\Glaucoma_Negative\620.jpg
# E:\Datasets\Glaucoma_detection\Fundus_Train_Val_Data\Fundus_Scanes_Sorted_And_Cropped_v2\Validation\Glaucoma_Negative\625.jpg
# E:\Datasets\Glaucoma_detection\Fundus_Train_Val_Data\Fundus_Scanes_Sorted_And_Cropped_v2\Validation\Glaucoma_Negative\629.jpg
# E:\Datasets\Glaucoma_detection\Fundus_Train_Val_Data\Fundus_Scanes_Sorted_And_Cropped_v2\Validation\Glaucoma_Negative\633.jpg
# E:\Datasets\Glaucoma_detection\Fundus_Train_Val_Data\Fundus_Scanes_Sorted_And_Cropped_v2\Validation\Glaucoma_Negative\635.jpg
# E:\Datasets\Glaucoma_detection\Fundus_Train_Val_Data\Fundus_Scanes_Sorted_And_Cropped_v2\Validation\Glaucoma_Negative\637.jpg
# E:\Datasets\Glaucoma_detection\Fundus_Train_Val_Data\Fundus_Scanes_Sorted_And_Cropped_v2\Validation\Glaucoma_Negative\639.jpg
# E:\Datasets\Glaucoma_detection\Fundus_Train_Val_Data\Fundus_Scanes_Sorted_And_Cropped_v2\Validation\Glaucoma_Negative\642.jpg
# E:\Datasets\Glaucoma_detection\Fundus_Train_Val_Data\Fundus_Scanes_Sorted_And_Cropped_v2\Validation\Glaucoma_Negative\643.jpg
# E:\Datasets\Glaucoma_detection\Fundus_Train_Val_Data\Fundus_Scanes_Sorted_And_Cropped_v2\Validation\Glaucoma_Negative\649.jpg
# E:\Datasets\Glaucoma_detection\Fundus_Train_Val_Data\Fundus_Scanes_Sorted_And_Cropped_v2\Validation\Glaucoma_Positive\598.jpg
#
# label Glaucoma_Positive, predicted Glaucoma_Negative
# E:\Datasets\Glaucoma_detection\Fundus_Train_Val_Data\Fundus_Scanes_Sorted_And_Cropped_v2\Validation\Glaucoma_Positive\600.jpg
#
# label Glaucoma_Positive, predicted Glaucoma_Negative
# E:\Datasets\Glaucoma_detection\Fundus_Train_Val_Data\Fundus_Scanes_Sorted_And_Cropped_v2\Validation\Glaucoma_Positive\601.jpg
#
# label Glaucoma_Positive, predicted Glaucoma_Negative
# E:\Datasets\Glaucoma_detection\Fundus_Train_Val_Data\Fundus_Scanes_Sorted_And_Cropped_v2\Validation\Glaucoma_Positive\604.jpg
#
# label Glaucoma_Positive, predicted Glaucoma_Negative
# E:\Datasets\Glaucoma_detection\Fundus_Train_Val_Data\Fundus_Scanes_Sorted_And_Cropped_v2\Validation\Glaucoma_Positive\605.jpg
#
# label Glaucoma_Positive, predicted Glaucoma_Negative
# E:\Datasets\Glaucoma_detection\Fundus_Train_Val_Data\Fundus_Scanes_Sorted_And_Cropped_v2\Validation\Glaucoma_Positive\608.jpg
#
# label Glaucoma_Positive, predicted Glaucoma_Negative
# E:\Datasets\Glaucoma_detection\Fundus_Train_Val_Data\Fundus_Scanes_Sorted_And_Cropped_v2\Validation\Glaucoma_Positive\609.jpg
#
# label Glaucoma_Positive, predicted Glaucoma_Negative
# E:\Datasets\Glaucoma_detection\Fundus_Train_Val_Data\Fundus_Scanes_Sorted_And_Cropped_v2\Validation\Glaucoma_Positive\612.jpg
#
# label Glaucoma_Positive, predicted Glaucoma_Negative
# E:\Datasets\Glaucoma_detection\Fundus_Train_Val_Data\Fundus_Scanes_Sorted_And_Cropped_v2\Validation\Glaucoma_Positive\613.jpg
#
# label Glaucoma_Positive, predicted Glaucoma_Negative
# E:\Datasets\Glaucoma_detection\Fundus_Train_Val_Data\Fundus_Scanes_Sorted_And_Cropped_v2\Validation\Glaucoma_Positive\615.jpg
#
# label Glaucoma_Positive, predicted Glaucoma_Negative
# E:\Datasets\Glaucoma_detection\Fundus_Train_Val_Data\Fundus_Scanes_Sorted_And_Cropped_v2\Validation\Glaucoma_Positive\617.jpg
#
# label Glaucoma_Positive, predicted Glaucoma_Negative
# E:\Datasets\Glaucoma_detection\Fundus_Train_Val_Data\Fundus_Scanes_Sorted_And_Cropped_v2\Validation\Glaucoma_Positive\618.jpg
#
# label Glaucoma_Positive, predicted Glaucoma_Negative
# E:\Datasets\Glaucoma_detection\Fundus_Train_Val_Data\Fundus_Scanes_Sorted_And_Cropped_v2\Validation\Glaucoma_Positive\619.jpg
#
# label Glaucoma_Positive, predicted Glaucoma_Negative
# E:\Datasets\Glaucoma_detection\Fundus_Train_Val_Data\Fundus_Scanes_Sorted_And_Cropped_v2\Validation\Glaucoma_Positive\621.jpg
#
# label Glaucoma_Positive, predicted Glaucoma_Negative
# E:\Datasets\Glaucoma_detection\Fundus_Train_Val_Data\Fundus_Scanes_Sorted_And_Cropped_v2\Validation\Glaucoma_Positive\622.jpg
#
# label Glaucoma_Positive, predicted Glaucoma_Negative
# E:\Datasets\Glaucoma_detection\Fundus_Train_Val_Data\Fundus_Scanes_Sorted_And_Cropped_v2\Validation\Glaucoma_Positive\623.jpg
#
# label Glaucoma_Positive, predicted Glaucoma_Negative
# E:\Datasets\Glaucoma_detection\Fundus_Train_Val_Data\Fundus_Scanes_Sorted_And_Cropped_v2\Validation\Glaucoma_Positive\624.jpg
#
# label Glaucoma_Positive, predicted Glaucoma_Negative
# E:\Datasets\Glaucoma_detection\Fundus_Train_Val_Data\Fundus_Scanes_Sorted_And_Cropped_v2\Validation\Glaucoma_Positive\626.jpg
#
# label Glaucoma_Positive, predicted Glaucoma_Negative
# E:\Datasets\Glaucoma_detection\Fundus_Train_Val_Data\Fundus_Scanes_Sorted_And_Cropped_v2\Validation\Glaucoma_Positive\627.jpg
#
# label Glaucoma_Positive, predicted Glaucoma_Negative
# E:\Datasets\Glaucoma_detection\Fundus_Train_Val_Data\Fundus_Scanes_Sorted_And_Cropped_v2\Validation\Glaucoma_Positive\628.jpg
#
# label Glaucoma_Positive, predicted Glaucoma_Negative
# E:\Datasets\Glaucoma_detection\Fundus_Train_Val_Data\Fundus_Scanes_Sorted_And_Cropped_v2\Validation\Glaucoma_Positive\630.jpg
#
# label Glaucoma_Positive, predicted Glaucoma_Negative
# E:\Datasets\Glaucoma_detection\Fundus_Train_Val_Data\Fundus_Scanes_Sorted_And_Cropped_v2\Validation\Glaucoma_Positive\631.jpg
#
# label Glaucoma_Positive, predicted Glaucoma_Negative
# E:\Datasets\Glaucoma_detection\Fundus_Train_Val_Data\Fundus_Scanes_Sorted_And_Cropped_v2\Validation\Glaucoma_Positive\632.jpg
#
# label Glaucoma_Positive, predicted Glaucoma_Negative
# E:\Datasets\Glaucoma_detection\Fundus_Train_Val_Data\Fundus_Scanes_Sorted_And_Cropped_v2\Validation\Glaucoma_Positive\634.jpg
#
# label Glaucoma_Positive, predicted Glaucoma_Negative
# E:\Datasets\Glaucoma_detection\Fundus_Train_Val_Data\Fundus_Scanes_Sorted_And_Cropped_v2\Validation\Glaucoma_Positive\636.jpg
#
# label Glaucoma_Positive, predicted Glaucoma_Negative
# E:\Datasets\Glaucoma_detection\Fundus_Train_Val_Data\Fundus_Scanes_Sorted_And_Cropped_v2\Validation\Glaucoma_Positive\638.jpg
#
# label Glaucoma_Positive, predicted Glaucoma_Negative
# E:\Datasets\Glaucoma_detection\Fundus_Train_Val_Data\Fundus_Scanes_Sorted_And_Cropped_v2\Validation\Glaucoma_Positive\640.jpg
#
# label Glaucoma_Positive, predicted Glaucoma_Negative
# E:\Datasets\Glaucoma_detection\Fundus_Train_Val_Data\Fundus_Scanes_Sorted_And_Cropped_v2\Validation\Glaucoma_Positive\641.jpg
#
# label Glaucoma_Positive, predicted Glaucoma_Negative
# E:\Datasets\Glaucoma_detection\Fundus_Train_Val_Data\Fundus_Scanes_Sorted_And_Cropped_v2\Validation\Glaucoma_Positive\644.jpg
#
# label Glaucoma_Positive, predicted Glaucoma_Negative
# E:\Datasets\Glaucoma_detection\Fundus_Train_Val_Data\Fundus_Scanes_Sorted_And_Cropped_v2\Validation\Glaucoma_Positive\645.jpg
#
# label Glaucoma_Positive, predicted Glaucoma_Negative
# E:\Datasets\Glaucoma_detection\Fundus_Train_Val_Data\Fundus_Scanes_Sorted_And_Cropped_v2\Validation\Glaucoma_Positive\646.jpg
#
# label Glaucoma_Positive, predicted Glaucoma_Negative
# E:\Datasets\Glaucoma_detection\Fundus_Train_Val_Data\Fundus_Scanes_Sorted_And_Cropped_v2\Validation\Glaucoma_Positive\647.jpg
#
# label Glaucoma_Positive, predicted Glaucoma_Negative
# E:\Datasets\Glaucoma_detection\Fundus_Train_Val_Data\Fundus_Scanes_Sorted_And_Cropped_v2\Validation\Glaucoma_Positive\648.jpg
#
# label Glaucoma_Positive, predicted Glaucoma_Negative
# E:\Datasets\Glaucoma_detection\Fundus_Train_Val_Data\Fundus_Scanes_Sorted_And_Cropped_v2\Validation\Glaucoma_Positive\650.jpg
#
# label Glaucoma_Positive, predicted Glaucoma_Negative

# %%
true_classified_images_count / total_images_count
# Out:
# 0.7384615384615385
